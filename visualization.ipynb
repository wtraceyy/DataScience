# %%
# %pip install seaborn matplotlib
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: matplotlib in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (3.11.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\roaming\python\python313\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# BEFORE ANY VISUALIZATION CODE , YOU MUST STATE THE QUESTION
# The question determines the chart , not the other way around

# %% [markdown]
# ### Matplotlib vs Seaborn
# Use seaborn for statistical visualization
# U se matplotlib for cutomisation and when seaborn doesn't have what we need

# %% [markdown]
# ### Figure and Axes
# In matplotlib , the canvas has 2 parts:
#    -the figure : the entire image
#    -the axes : individual plots within the figure

# %% [markdown]
# ### plt.figure() - creating the canvas

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
fig =plt.figure(figsize = (10,6), dpi=100, facecolor='white', edgecolor='black', linewidth =2)

# %% [markdown]
# ### plt.subplots() - multiple plots

# %%
fig,axis = plt.subplots(nrows=2, ncols=3, figsize=(15,10), sharex=False, sharey=False)

# %% [markdown]
# ### Line plot
# Shows changes over a continuous variable(usually time) trends , patterns , cycles
# When to use: Time series data , showing progression , comparing trends across groups
# When not to use: Categorical x-axis (use bar chart instead), no natural ordering in x-axis

# %%
plt.plot('age','salary_kes',
         data= df,
         color = '#2196F3',          #line color
         linestyle = '-',           # solid line
         linewidth = 2,              #line thickness
         marker ='o',
         markersize = 6,
         markerfacecolor ='white',   #hollow markers
         markeredgecolor='#2196F3',
         alpha = 0.8,                #transparency
         label ='Revenue 2024',      #legend label
         zorder = 3,                 #draw on top
         )

plt.show()

# %%
# Kenyantech prffesionals dataset
data = {
       'name':         ['Aisha', 'Brian', 'Celestine', 'David', 'Esther', 
                     'Felix', 'Grace', 'Hassan', 'Ivy', 'James', 
                     'Kendi', 'Liban', 'Mary', 'Noel', 'Olive'], 

    'job_title':    ['Data Analyst', 'Software Engineer', 'Data Scientist', 'DevOps Engineer', 'Data Analyst', 
                     'ML Engineer', 'Software Engineer', 'Data Scientist', 'Data Analyst', 'Software Engineer', 
                     'ML Engineer', 'DevOps Engineer', 'Data Scientist', 'Data Analyst', 'Software Engineer'], 

    'city':         ['Nairobi', 'Mombasa', 'Nairobi', 'Kisumu', 'Nairobi', 
                     'Nairobi', 'Mombasa', 'Nairobi', 'Nakuru', 'Nairobi', 
                     'Kisumu', 'Nairobi', 'Mombasa', 'Nairobi', 'Nairobi'], 

    'salary_kes':   [85000, 120000, 150000, 110000, 78000, 
                     175000, 115000, 160000, 72000, 130000, 
                     180000, 105000, 145000, 80000, 125000], 

    'experience_yrs': [2, 4, 5, 3, 1, 6, 4, 7, 1, 5, 7, 3, 6, 2, 4], 

    'employment_type': ['Full-time', 'Full-time', 'Contract', 'Full-time', 'Part-time', 
                        'Full-time', 'Contract', 'Full-time', 'Part-time', 'Full-time', 
                        'Full-time', 'Contract', 'Full-time', 'Full-time', 'Contract'], 

    'age':          [25, 28, 30, 27, 24, 32, 29, 35, 23, 31, 34, 26, 33, 25, 28], 

    'joined_date':  ['2022-03-15', '2020-07-01', '2019-11-20', '2021-05-10', '2023-01-08', 
                     '2018-09-03', '2020-12-15', '2017-04-22', '2023-02-14', '2019-06-30', 
                     '2017-08-11', '2021-03-25', '2018-05-17', '2022-09-01', '2020-11-10'], 
                     
    'salary_history_2022': [70000, 100000, None, 95000, None, 
                             150000, 100000, 140000, None, 115000, 
                             160000, 90000, 130000, 65000, 110000] 
}


df = pd.DataFrame(data)
print(df)
# Out:
#          name          job_title     city  salary_kes  experience_yrs  \
# 0       Aisha       Data Analyst  Nairobi       85000               2
# 1       Brian  Software Engineer  Mombasa      120000               4
# 2   Celestine     Data Scientist  Nairobi      150000               5
# 3       David    DevOps Engineer   Kisumu      110000               3
# 4      Esther       Data Analyst  Nairobi       78000               1
# 5       Felix        ML Engineer  Nairobi      175000               6
# 6       Grace  Software Engineer  Mombasa      115000               4
# 7      Hassan     Data Scientist  Nairobi      160000               7
# 8         Ivy       Data Analyst   Nakuru       72000               1
# 9       James  Software Engineer  Nairobi      130000               5
# 10      Kendi        ML Engineer   Kisumu      180000               7
# 11      Liban    DevOps Engineer  Nairobi      105000               3
# 12       Mary     Data Scientist  Mombasa      145000               6
# 13       Noel       Data Analyst  Nairobi       80000               2
# 14      Olive  Software Engineer  Nairobi      125000               4
#
#    employment_type  age joined_date  salary_history_2022
# 0        Full-time   25  2022-03-15              70000.0
# 1        Full-time   28  2020-07-01             100000.0
# 2         Contract   30  2019-11-20                  NaN
# 3        Full-time   27  2021-05-10              95000.0
# 4        Part-time   24  2023-01-08                  NaN
# 5        Full-time   32  2018-09-03             150000.0
# 6         Contract   29  2020-12-15             100000.0
# 7        Full-time   35  2017-04-22             140000.0
# 8        Part-time   23  2023-02-14                  NaN
# 9        Full-time   31  2019-06-30             115000.0
# 10       Full-time   34  2017-08-11             160000.0
# 11        Contract   26  2021-03-25              90000.0
# 12       Full-time   33  2018-05-17             130000.0
# 13       Full-time   25  2022-09-01              65000.0
# 14        Contract   28  2020-11-10             110000.0

# %%
# Seaborn: sns.lineplot
sns.lineplot(data = df, x='age', y='salary_kes', markers = True, dashes = False, palette = 'Sets2', linewidth = 2,err_style = 'band', ci=95, estimator = 'mean')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18868\1477077130.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 95)` for the same effect.
#
#   sns.lineplot(data = df, x='age', y='salary_kes', markers = True, dashes = False, palette = 'Sets2', linewidth = 2,err_style = 'band', ci=95, estimator = 'mean')
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18868\1477077130.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = df, x='age', y='salary_kes', markers = True, dashes = False, palette = 'Sets2', linewidth = 2,err_style = 'band', ci=95, estimator = 'mean')
# <Axes: xlabel='age', ylabel='salary_kes'>
